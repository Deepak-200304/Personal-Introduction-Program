# %%
# User information
name = input("What is your name?")
age = input("How old are you?")
hobby = input("What is your favorite hobby?")
city = input("Which city do you live in?")
profession = input("What is your profession or field of study?")
favorite_food = input("What is your favorite food?")
sport = input("What is your favourite sport?")
# Out:
# What is your name? Deepak Tyagi
# How old are you? 22
# What is your favorite hobby? Sketching
# Which city do you live in? Delhi
# What is your profession or field of study? MCA
# What is your favorite food? Rajma Chawal
# What is your favourite sport? Kabaddi

# %%
# Display a friendly welcome message
print("\n--- Welcome Message ---")
print(f"Hello {name}! ")
print(f"It's wonderful to meet you!")

#Age and City
print(f"You are {age} years old and live in {city}.")

#Hobby, Favourite food and Profession
print(f"You enjoy {hobby}, love eating {favorite_food}, and work/study in {profession}.")

#Favourite Sport
print(f"Your love the '{sport}' and its a nice sport!")
print("\nWe're excited to have you here!")
# Out:
# --- Welcome Message ---
# Hello Deepak Tyagi!
# It's wonderful to meet you!
# You are 22 years old and live in Delhi.
# You enjoy Sketching, love eating Rajma Chawal, and work/study in MCA.
# Your love the 'Kabaddi' and its a nice sport!
#
# We're excited to have you here!
